# %% [markdown]
# <a href="https://colab.research.google.com/github/LeeSeoHyeon375/Iot-class-assignment/blob/main/Iot_assignment_04_04(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install paho-mqtt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.9/66.9 kB 1.4 MB/s eta 0:00:00
# ...

# %%
import json
import requests
n=0

def doit(topic, payload):
  global n
  print(topic, payload)
  j=json.loads(payload)
  #print(j['co2'])
  url = 'https://api.thingspeak.com/update?api_key=LJBRUCSX7PDV5XNQ&field1'
  url += '&field1='+j['co2']
  url += '&field2='+j['bme680'].split(',')[0]
  if n>15:
    r=requests.get(url)
    print(url, r.text)
    n=0
  n+=1

# %%
import paho.mqtt.client as mqtt

def on_connect(client, userdata, flags, reason_code, properties):
  print(f"Connected with result code {reason_code}")
  client.subscribe("connectware/indoor/data/1502")

def on_message(client, userdata, msg):
  doit(msg.topic, msg.payload.decode('utf8'))

client = mqtt.Client(mqtt.CallbackAPIVersion.VERSION2)
client.on_connect = on_connect
client.on_message = on_message

client.connect("damoa.io", 1883, 60)
client.loop_forever()
# Out:
# Connected with result code Success
# connectware/indoor/data/1502 {"dust":"47,63","co2":"467","bme680":"26.38,18.13,3572867,100747,48.23","time":"2024-04-07 16:51:49", "serial":259823, "ip":"203.255.190.49"}
# connectware/indoor/data/1502 {"dust":"47,64","co2":"467","bme680":"26.38,18.14,3594594,100746,48.40","time":"2024-04-07 16:51:50", "serial":259824, "ip":"203.255.190.49"}
# connectware/indoor/data/1502 {"dust":"47,63","co2":"468","bme680":"26.38,18.15,3589743,100744,48.48","time":"2024-04-07 16:51:51", "serial":259825, "ip":"203.255.190.49"}
# connectware/indoor/data/1502 {"dust":"45,60","co2":"468","bme680":"26.38,18.13,3553774,100744,48.40","time":"2024-04-07 16:51:52", "serial":259826, "ip":"203.255.190.49"}
# connectware/indoor/data/1502 {"dust":"45,60","co2":"468","bme680":"26.38,18.14,3570469,100746,48.23","time":"2024-04-07 16:51:53", "serial":259827, "ip":"203.255.190.49"}
# ...
